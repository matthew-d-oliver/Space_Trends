# %%
import re
import os
import time
import random
import requests
import gensim
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os import system

# %%
from pytrends.request import TrendReq
#need to update pandas and restart jupyter notebook after importing pytrends

pytrends = TrendReq(hl='en-US', tz=360, timeout=(10,25), retries=2, backoff_factor=0.1)

# %%
start_time = time.time()
# your code2015-01-03

testy2=pytrends.get_historical_interest(['space exploration'],
                                       year_start=2014,
                                       month_start=12, 
                                       day_start=30, 
                                       hour_start=0, 
                                       year_end=2015, 
                                       month_end=1, 
                                       day_end=20, 
                                       hour_end=0, 
                                       cat=0, 
                                       geo='US', 
                                       gprop='', 
                                       sleep=60)
# testy.to_csv('hourly_09-19')
elapsed_time = time.time() - start_time
print('time: {}\nyears:{}-{}'.format(elapsed_time,2016,2019))
# Out:
# time: 121.92843699455261
# years:2016-2019

# %%
weekly1=pd.read_csv('09-14_spaceex.csv',index_col=0,skiprows=[0,1])
weekly2=pd.read_csv('14-19_spaceex.csv',index_col=0,skiprows=[0,1])

# %%
weekly=pd.concat([weekly1,weekly2])

# %%
weekly.plot()

# %%
testy.plot()
